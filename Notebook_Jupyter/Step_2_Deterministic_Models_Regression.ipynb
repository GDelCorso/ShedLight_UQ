# %% [markdown]
# # Chapter 2: Deterministic models
# This chapter aims to show two regression models defined in Pytorch from scratches.

# %%
# Libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from pathlib import Path

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

path_pardir = Path(os.getcwd()).parent
path_data = os.path.join(path_pardir, 'Data')

# %% [markdown]
# ## S2-1: A standard regression model
# This is an elementary implementation of a regression model in Pytorch.
#
# First, we define the device (GPU/CPU) we are working with:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# The data frame is the linear relationship without noise introduced in step_1, we explicitly split the data frame into training/validation/test set.

# %%
chosen_df = "df_linear.csv"

full_df = pd.read_csv(os.path.join(path_data, chosen_df))

training_df = full_df[full_df["split_label"]==0]
validation_df = full_df[full_df["split_label"]==1]
test_df = full_df[full_df["split_label"]==2]

full_df.head(8)
# Out:
#       x_range     y_range  split_label
# 0 -100.000000 -193.000000            0
# 1  -98.994975 -190.989950            2
# 2  -97.989950 -188.979899            0
# 3  -96.984925 -186.969849            0
# 4  -95.979899 -184.959799            0
# 5  -94.974874 -182.949749            0
# 6  -93.969849 -180.939698            0
# 7  -92.964824 -178.929648            1

# %% [markdown]
# We define a CustomDataset from Pytorch Dataset. The dataset has an *init* (initialise the class), a *len* and a *getitem* method.
# A Dataset must provide the tools to identify available data and return all the elements needed to train/test/evaluate the model.
#
# Can be skipped if the data is particularly simple.

# %%
# Dataset definition:
class CustomDataset(Dataset):
    def __init__(self, annotations_file, path_data, split_label=None):
        if split_label!=None:
            self.df = pd.read_csv(os.path.join(path_data, annotations_file))
            self.df = self.df[self.df['split_label']==split_label]
        else:
            self.df = pd.read_csv(os.path.join(path_data, annotations_file))

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        x_range = float(self.df.iloc[idx]['x_range'])
        y_range = float(self.df.iloc[idx]['y_range'])

        features = torch.tensor([x_range], dtype=torch.float32)
        output = torch.tensor([y_range], dtype=torch.float32)
        
        return features, output

# Initialize Training dataset and show outputs and properties:
training_dataset = CustomDataset(annotations_file=chosen_df, path_data=path_data, split_label=0)
print("Length training dataset:", training_dataset.__len__())

index_example = 27
print(f"Output example (x_range,y_range)=({training_dataset.__getitem__(index_example)}) with index {index_example}.")

# Initialize validation and test datasets:
validation_dataset = CustomDataset(annotations_file=chosen_df, path_data=path_data, split_label=1)
test_dataset = CustomDataset(annotations_file=chosen_df, path_data=path_data, split_label=2)
# Out:
# Length training dataset: 160
# Output example (x_range,y_range)=((tensor([-63.8191]), tensor([-120.6382]))) with index 27.

# %% [markdown]
# To define a batch we can iterate on the whole dataset or define a *DataLoader* which samples from the introduced DataSet and can be iterated during training. It provides a batch of tensors to apply the computations efficiently at the same time.

# %%
# Size of each batch
batch_size = 10  

# Define 3 DataLoaders: Training/Validation/Test 
training_dataloader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size=1, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# An example of iteration on the DataLoader:
x_example, y_example = next(iter(training_dataloader))
print(f"(x_example,y_example)=({x_example},{y_example})")
print(f"Data loaded shape: {x_example.shape}")
# Out:
# (x_example,y_example)=(tensor([[-78.8945],
#         [ 17.5879],
#         [ 26.6332],
#         [-34.6734],
#         [-50.7538],
#         [ 39.6985],
#         [-41.7085],
#         [-79.8995],
#         [ 52.7638],
#         [ 78.8945]]),tensor([[-150.7889],
#         [  42.1759],
#         [  60.2663],
#         [ -62.3467],
#         [ -94.5075],
#         [  86.3970],
#         [ -76.4171],
#         [-152.7990],
#         [ 112.5276],
#         [ 164.7889]]))
# Data loaded shape: torch.Size([10, 1])

# %% [markdown]
# Introduce a (small) model to approximate the relationship:

# %%
# Define the model:
model = nn.Sequential(
    nn.Linear(1, 4),
    nn.ReLU(),
    nn.Linear(4,4),
    nn.ReLU(),
    nn.Linear(4, 1)
)

# Move the model to device (GPU):
model.to(device)

# Convert weights type to float:
model = model.float()

# %% [markdown]
# To define a more complex model (instead of a sequential one), we can explicitely define it from the torch.nn.Module as follows:

# %%
class CustomRegressionANN(nn.Module):
    def __init__(self):
        super(CustomRegressionANN, self).__init__()
        
        # Define the layers to be used in the forward pass:
        self.fc1 = nn.Linear(1, 4)  # First Linear layer (input size: 1, output size: 4)
        self.fc2 = nn.Linear(4, 4)  # Second Linear layer (input size: 4, output size: 4)
        self.fc3 = nn.Linear(4, 1)  # Third Linear layer (input size: 4, output size: 1)
        
        self.relu = nn.ReLU()       # ReLU activation function

    def forward(self, x):
        # Define the forward pass explicitly (by telling the network how to combine the previous layers)
        x = self.fc1(x)             # Pass through the first layer
        x = self.relu(x)            # Apply ReLU activation
        
        x = self.fc2(x)             # Pass through the second layer
        x = self.relu(x)            # Apply ReLU activation
        
        x = self.fc3(x)             # Pass through the final layer
        
        return x

# Make an instance of the custom ANN defined
model = CustomRegressionANN()

# Move the model to device (GPU):
model.to(device)

# Convert weights type to float:
model = model.float()

# %% [markdown]
# Introduce the loss and the optimiser. Both can be implemented explicitly. The loss can be any function relating predictions and ground truths.

# %%
# Loss function (Mean Squared Error):
loss_fn = nn.MSELoss()  

# Optimizer (Adam): 
learning_rate = 1e-2
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# Training cycle:
# - The model is trained for a given number of epochs *n_epochs*
# - Each epoch iterates over the entire dataset (*shuffle == True* just randomly shuffles indices) using the dataloader to generate batches.
# - For each batch, the gradients are computed on the whole batch to the respect of the loss function and the optimizer it is used to update model trainable parameters

# %%
# Number of training epochs:
n_epochs = 100

training_loss_list = []
validation_loss_list = []

# Iterate over the epochs:
for epoch in range(n_epochs):

    # Set the model to Training mode: This interacts with certain kind of network layers (such as Dropout layers)
    model.train()  

    # Temporary variable to store the loss on the whole epoch as a convergence metric
    running_loss = 0.0

    # Iterate on the whole dataset using the dataloader.
    for x_input, y_output in training_dataloader:
        # Load inputs ad move to device (GPU)
        x_input, y_output = x_input.to(device), y_output.to(device)

        # Clear previous gradients
        optimizer.zero_grad()  
        
        # Forward pass (model calls)
        y_model = model(x_input)  

        # Compute loss (supervised case)
        loss = loss_fn(y_model, y_output)  
        
        # Backpropagation 
        loss.backward()  

        # Update parameters (optimization step)
        optimizer.step()  

        # Update running loss as convergence metric
        running_loss += loss.item()
        

    
    ## Calculate loss on validation as an additional metric to evaluate overfitting
    # Set the model to Evaluation mode:
    model.eval()

    # Temporary variable to store the validation loss:
    running_val_loss = 0.0
    
    # Deactivate gradient computation
    with torch.no_grad():
        for x_input, y_output in validation_dataloader:
            # Load inputs ad move to device (GPU)
            x_input, y_output = x_input.to(device), y_output.to(device)

        
            # Forward pass (model calls)
            y_model = model(x_input)

            # Compute loss (supervised case)
            loss = loss_fn(y_model, y_output)

            # Update validation running loss as convergence metric
            running_val_loss += loss.item()
            
    # Average epoch loss
    epoch_training_loss = running_loss / len(training_dataloader)
    epoch_validation_loss = running_val_loss / len(validation_dataloader)

    # Append the losses to the list:
    training_loss_list.append(epoch_training_loss)
    validation_loss_list.append(epoch_validation_loss)
            
    # Convergence metric
    print(f"Epoch [{epoch+1}/{n_epochs}], Loss: {epoch_training_loss:.4f}, Val. Loss: {epoch_validation_loss:.4f}")
# Out:
# Epoch [1/100], Loss: 12365.7810, Val. Loss: 12634.6736
# Epoch [2/100], Loss: 10686.6777, Val. Loss: 9812.8264
# Epoch [3/100], Loss: 7374.5594, Val. Loss: 5100.8870
# Epoch [4/100], Loss: 2871.4928, Val. Loss: 827.1818
# Epoch [5/100], Loss: 246.8186, Val. Loss: 81.4423
# Epoch [6/100], Loss: 81.7504, Val. Loss: 29.6566
# Epoch [7/100], Loss: 16.9417, Val. Loss: 19.3190
# Epoch [8/100], Loss: 15.5205, Val. Loss: 13.3021
# Epoch [9/100], Loss: 11.9998, Val. Loss: 13.3685
# Epoch [10/100], Loss: 11.8251, Val. Loss: 12.8238
# Epoch [11/100], Loss: 11.5768, Val. Loss: 12.6811
# Epoch [12/100], Loss: 11.4524, Val. Loss: 12.3207
# Epoch [13/100], Loss: 11.2901, Val. Loss: 12.1016
# Epoch [14/100], Loss: 10.9810, Val. Loss: 11.8092
# Epoch [15/100], Loss: 10.6330, Val. Loss: 11.5509
# Epoch [16/100], Loss: 10.4536, Val. Loss: 11.1668
# Epoch [17/100], Loss: 10.1330, Val. Loss: 10.9240
# Epoch [18/100], Loss: 9.8926, Val. Loss: 10.5138
# Epoch [19/100], Loss: 9.5698, Val. Loss: 9.8221
# Epoch [20/100], Loss: 8.5345, Val. Loss: 9.2970
# Epoch [21/100], Loss: 7.7515, Val. Loss: 8.1285
# Epoch [22/100], Loss: 7.1309, Val. Loss: 8.6540
# Epoch [23/100], Loss: 7.6786, Val. Loss: 7.6772
# Epoch [24/100], Loss: 6.9984, Val. Loss: 7.2711
# Epoch [25/100], Loss: 6.5971, Val. Loss: 7.2631
# Epoch [26/100], Loss: 6.2463, Val. Loss: 6.7124
# Epoch [27/100], Loss: 5.9161, Val. Loss: 6.5554
# Epoch [28/100], Loss: 5.8538, Val. Loss: 6.2825
# Epoch [74/100], Loss: 0.4251, Val. Loss: 0.4870
# Epoch [75/100], Loss: 0.4356, Val. Loss: 0.4185
# Epoch [76/100], Loss: 0.3222, Val. Loss: 0.3342
# Epoch [77/100], Loss: 0.3253, Val. Loss: 0.3995
# Epoch [78/100], Loss: 0.3178, Val. Loss: 0.2953
# Epoch [79/100], Loss: 0.2585, Val. Loss: 0.2770
# Epoch [80/100], Loss: 0.2409, Val. Loss: 0.2484
# Epoch [81/100], Loss: 0.2233, Val. Loss: 0.2402
# Epoch [82/100], Loss: 0.2131, Val. Loss: 0.2298
# Epoch [83/100], Loss: 0.2308, Val. Loss: 0.2199
# Epoch [84/100], Loss: 0.2295, Val. Loss: 0.1963
# Epoch [85/100], Loss: 0.1810, Val. Loss: 0.1604
# Epoch [86/100], Loss: 0.1678, Val. Loss: 0.1634
# Epoch [87/100], Loss: 0.1554, Val. Loss: 0.1351
# Epoch [88/100], Loss: 0.1560, Val. Loss: 0.1687
# Epoch [89/100], Loss: 0.1286, Val. Loss: 0.1205
# Epoch [90/100], Loss: 0.1192, Val. Loss: 0.1045
# Epoch [91/100], Loss: 0.1106, Val. Loss: 0.0975
# Epoch [92/100], Loss: 0.1131, Val. Loss: 0.1041
# Epoch [93/100], Loss: 0.1039, Val. Loss: 0.0908
# Epoch [94/100], Loss: 0.1091, Val. Loss: 0.0908
# Epoch [95/100], Loss: 0.0974, Val. Loss: 0.0706
# Epoch [96/100], Loss: 0.0786, Val. Loss: 0.0735
# Epoch [97/100], Loss: 0.0758, Val. Loss: 0.0589
# Epoch [98/100], Loss: 0.0699, Val. Loss: 0.0548
# Epoch [99/100], Loss: 0.0653, Val. Loss: 0.0527
# Epoch [100/100], Loss: 0.0589, Val. Loss: 0.0467

# %% [markdown]
# Plot the convergence graphs on training and validation sets:

# %%
fig, ax = plt.subplots()

ax.plot(list(range(len(training_loss_list))), training_loss_list, color = 'black', label='Training loss')
ax.plot(list(range(len(validation_loss_list))), validation_loss_list,  color = 'red', label='Validation loss')
ax.legend()

# %% [markdown]
# Plot the training dataset against the predictions:

# %%
# Define the dataframe 
x_plot = np.array(training_df["x_range"]) # Input
y_plot = np.array(training_df["y_range"]) # GT
prediction_plot = [float(model(torch.tensor(i).view(1).to(device).float()).to('cpu')) for i in x_plot] # Predictions

df_plot_train = pd.DataFrame({"x":np.append(x_plot,x_plot),"y":np.append(y_plot,prediction_plot),"GT/Pred":np.append(["GT"]*len(y_plot), ["Pred"]*len(prediction_plot))})
                         
# Scatter plot
sns.scatterplot(data=df_plot_train, x="x", y="y", hue="GT/Pred", alpha = 0.3)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Plot the test dataset against the predictions:

# %%
# Define the dataframe 
x_plot = np.array(test_df["x_range"]) # Input
y_plot = np.array(test_df["y_range"]) # GT
prediction_plot = [float(model(torch.tensor(i).view(1).to(device).float()).to('cpu')) for i in x_plot] # Predictions

df_plot_test = pd.DataFrame({"x":np.append(x_plot,x_plot),"y":np.append(y_plot,prediction_plot),"GT/Pred":np.append(["GT"]*len(y_plot), ["Pred"]*len(prediction_plot))})
                         
# Scatter plot
sns.scatterplot(data=df_plot_test, x="x", y="y", hue="GT/Pred", alpha = 0.3)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ## S2-2: Regression on noisy data:
# we want to apply the same method on a noisy dataset.

# %%
chosen_df = "df_nonlinear_heteroscedastic_aleatoric.csv"

full_df = pd.read_csv(os.path.join(path_data, chosen_df))

training_df = full_df[full_df["split_label"]==0]
validation_df = full_df[full_df["split_label"]==1]
test_df = full_df[full_df["split_label"]==2]

print(len(full_df))

full_df.head(8)
# Out:
# 2000
#      x_range   y_range  split_label
# 0 -100.00000 -2.301985            0
# 1  -99.89995 -1.904300            0
# 2  -99.79990 -1.670993            2
# 3  -99.69985 -2.122477            2
# 4  -99.59980 -1.778223            0
# 5  -99.49975 -2.057319            1
# 6  -99.39970 -2.118222            0
# 7  -99.29965 -2.110165            0

# %%
# Initilize Training dataset and show outputs and properties:
training_dataset = CustomDataset(annotations_file=chosen_df, path_data=path_data, split_label=0)

# Initialize validation and test datasets:
validation_dataset = CustomDataset(annotations_file=chosen_df, path_data=path_data, split_label=1)
test_dataset = CustomDataset(annotations_file=chosen_df, path_data=path_data, split_label=2)

# %%
# Size of each batch
batch_size = 10  

# Define 3 DataLoaders: Training/Validation/Test 
training_dataloader = DataLoader(training_dataset, batch_size=batch_size, shuffle=True)
validation_dataloader = DataLoader(validation_dataset, batch_size=1, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Define the model:
model = nn.Sequential(
    nn.Linear(1, 8),
    nn.ReLU(),
    nn.Linear(8, 16),
    nn.ReLU(),
    nn.Linear(16, 32),
    nn.ReLU(),
    nn.Linear(32, 16),
    nn.ReLU(),
    nn.Linear(16, 16),
    nn.ReLU(),
    nn.Linear(16, 1)
)

# Move the model to device (GPU):
model.to(device)

# Convert weights type to float:
model = model.float()

# %%
# Loss function (Mean Squared Error):
loss_fn = nn.MSELoss()  

# Optimizer (Adam): 
learning_rate = 1e-3
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Number of training epochs:
n_epochs = 100

training_loss_list = []
validation_loss_list = []

# Iterate over the epochs:
for epoch in range(n_epochs):

    # Set the model to Training mode: This interacts with certain kind of network layers (such as Dropout layers)
    model.train()  

    # Temporary variable to store the loss on the whole epoch as a convergence metric
    running_loss = 0.0

    # Iterate on the whole dataset using the dataloader.
    for x_input, y_output in training_dataloader:
        # Load inputs ad move to device (GPU)
        x_input, y_output = x_input.to(device), y_output.to(device)

        # Clear previous gradients
        optimizer.zero_grad()  
        
        # Forward pass (model calls)
        y_model = model(x_input)  

        # Compute loss (supervised case)
        loss = loss_fn(y_model, y_output)  
        
        # Backpropagation 
        loss.backward()  

        # Update parameters (optimization step)
        optimizer.step()  

        # Update running loss as convergence metric
        running_loss += loss.item()
        

    
    ## Calculate loss on validation as an additional metric to evaluate overfitting
    # Set the model to Evaluation mode:
    model.eval()

    # Temporary variable to store the validation loss:
    running_val_loss = 0.0
    
    # Deactivate gradient computation
    with torch.no_grad():
        for x_input, y_output in validation_dataloader:
            # Load inputs ad move to device (GPU)
            x_input, y_output = x_input.to(device), y_output.to(device)

        
            # Forward pass (model calls)
            y_model = model(x_input)

            # Compute loss (supervised case)
            loss = loss_fn(y_model, y_output)

            # Update validation running loss as convergence metric
            running_val_loss += loss.item()
            
    # Average epoch loss
    epoch_training_loss = running_loss / len(training_dataloader)
    epoch_validation_loss = running_val_loss / len(validation_dataloader)

    # Append the losses to the list:
    training_loss_list.append(epoch_training_loss)
    validation_loss_list.append(epoch_validation_loss)
            

    # Convergence metric
    print(f"Epoch [{epoch+1}/{n_epochs}], Loss: {epoch_training_loss:.4f}, Val. Loss: {epoch_validation_loss:.4f}")
# Out:
# Epoch [1/100], Loss: 0.7368, Val. Loss: 0.4383
# Epoch [2/100], Loss: 0.3387, Val. Loss: 0.2385
# Epoch [3/100], Loss: 0.2033, Val. Loss: 0.1589
# Epoch [4/100], Loss: 0.1589, Val. Loss: 0.1334
# Epoch [5/100], Loss: 0.1360, Val. Loss: 0.1195
# Epoch [6/100], Loss: 0.1247, Val. Loss: 0.1138
# Epoch [7/100], Loss: 0.1128, Val. Loss: 0.1115
# Epoch [8/100], Loss: 0.1085, Val. Loss: 0.1052
# Epoch [9/100], Loss: 0.1019, Val. Loss: 0.1000
# Epoch [10/100], Loss: 0.0989, Val. Loss: 0.1105
# Epoch [11/100], Loss: 0.0961, Val. Loss: 0.0924
# Epoch [12/100], Loss: 0.0894, Val. Loss: 0.0915
# Epoch [13/100], Loss: 0.0884, Val. Loss: 0.0874
# Epoch [14/100], Loss: 0.0898, Val. Loss: 0.1038
# Epoch [15/100], Loss: 0.0862, Val. Loss: 0.1107
# Epoch [16/100], Loss: 0.0779, Val. Loss: 0.0747
# Epoch [17/100], Loss: 0.0700, Val. Loss: 0.0682
# Epoch [18/100], Loss: 0.0664, Val. Loss: 0.1219
# Epoch [19/100], Loss: 0.0735, Val. Loss: 0.0565
# Epoch [20/100], Loss: 0.0684, Val. Loss: 0.0617
# Epoch [21/100], Loss: 0.0550, Val. Loss: 0.0467
# Epoch [22/100], Loss: 0.0538, Val. Loss: 0.0500
# Epoch [23/100], Loss: 0.0577, Val. Loss: 0.0522
# Epoch [24/100], Loss: 0.0467, Val. Loss: 0.0515
# Epoch [25/100], Loss: 0.0428, Val. Loss: 0.0489
# Epoch [26/100], Loss: 0.0445, Val. Loss: 0.0499
# Epoch [27/100], Loss: 0.0400, Val. Loss: 0.0439
# Epoch [28/100], Loss: 0.0355, Val. Loss: 0.0534
# Epoch [29/100], Loss: 0.0434, Val. Loss: 0.0472
# Epoch [30/100], Loss: 0.0421, Val. Loss: 0.0968
# Epoch [31/100], Loss: 0.0478, Val. Loss: 0.0352
# Epoch [32/100], Loss: 0.0431, Val. Loss: 0.0615
# Epoch [77/100], Loss: 0.0292, Val. Loss: 0.0282
# Epoch [78/100], Loss: 0.0299, Val. Loss: 0.0335
# Epoch [79/100], Loss: 0.0283, Val. Loss: 0.0234
# Epoch [80/100], Loss: 0.0258, Val. Loss: 0.0345
# Epoch [81/100], Loss: 0.0304, Val. Loss: 0.0389
# Epoch [82/100], Loss: 0.0266, Val. Loss: 0.0277
# Epoch [83/100], Loss: 0.0272, Val. Loss: 0.0283
# Epoch [84/100], Loss: 0.0278, Val. Loss: 0.0319
# Epoch [85/100], Loss: 0.0341, Val. Loss: 0.0316
# Epoch [86/100], Loss: 0.0257, Val. Loss: 0.0293
# Epoch [87/100], Loss: 0.0325, Val. Loss: 0.0308
# Epoch [88/100], Loss: 0.0334, Val. Loss: 0.0298
# Epoch [89/100], Loss: 0.0295, Val. Loss: 0.0380
# Epoch [90/100], Loss: 0.0272, Val. Loss: 0.0217
# Epoch [91/100], Loss: 0.0278, Val. Loss: 0.0260
# Epoch [92/100], Loss: 0.0272, Val. Loss: 0.0289
# Epoch [93/100], Loss: 0.0266, Val. Loss: 0.0258
# Epoch [94/100], Loss: 0.0361, Val. Loss: 0.0541
# Epoch [95/100], Loss: 0.0358, Val. Loss: 0.0281
# Epoch [96/100], Loss: 0.0289, Val. Loss: 0.0227
# Epoch [97/100], Loss: 0.0266, Val. Loss: 0.0215
# Epoch [98/100], Loss: 0.0248, Val. Loss: 0.0321
# Epoch [99/100], Loss: 0.0266, Val. Loss: 0.0241
# Epoch [100/100], Loss: 0.0253, Val. Loss: 0.0283

# %%
fig, ax = plt.subplots()

ax.plot(list(range(len(training_loss_list))), training_loss_list, color = 'black', label='Training loss')
ax.plot(list(range(len(validation_loss_list))), validation_loss_list,  color = 'red', label='Validation loss')
ax.legend()

# %%
# Define the dataframe 
x_plot = np.array(training_df["x_range"]) # Input
y_plot = np.array(training_df["y_range"]) # GT
prediction_plot = [float(model(torch.tensor(i).view(1).to(device).float()).to('cpu')) for i in x_plot] # Predictions

df_plot_train = pd.DataFrame({"x":np.append(x_plot,x_plot),"y":np.append(y_plot,prediction_plot),"GT/Pred":np.append(["GT"]*len(y_plot), ["Pred"]*len(prediction_plot))})
                         
# Scatter plot
sns.scatterplot(data=df_plot_train, x="x", y="y", hue="GT/Pred", alpha = 0.3)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
# Define the dataframe 
x_plot = np.array(test_df["x_range"]) # Input
y_plot = np.array(test_df["y_range"]) # GT
prediction_plot = [float(model(torch.tensor(i).view(1).to(device).float()).to('cpu')) for i in x_plot] # Predictions

df_plot_test = pd.DataFrame({"x":np.append(x_plot,x_plot),"y":np.append(y_plot,prediction_plot),"GT/Pred":np.append(["GT"]*len(y_plot), ["Pred"]*len(prediction_plot))})
                         
# Scatter plot
sns.scatterplot(data=df_plot_test, x="x", y="y", hue="GT/Pred", alpha = 0.3)
# Out:
# <Axes: xlabel='x', ylabel='y'>
